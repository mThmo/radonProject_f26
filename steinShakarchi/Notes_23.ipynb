# %% [markdown]
# # Ch 2

# %% [markdown]
# ## Fourier Series, fourier coefficients

# %% [markdown]
# ### Partial sums

# %% [markdown]
# #### Ceasaro summability

# %% [markdown]
# #### Abel summability

# %% [markdown]
# ## Function spaces

# %% [markdown]
# ### vector spaces, inner products

# %% [markdown]
# #### orthonormality

# %% [markdown]
# ### Riemainn integrability, boundedness

# %% [markdown]
# ### Hilbert space

# %% [markdown]
# #### Mean square convergence

# %% [markdown]
# #### Uniform convergence

# %% [markdown]
# #### Lipschitz condition

# %% [markdown]
# ## Kernels

# %% [markdown]
# ### Convolutions

# %% [markdown]
# ### Dirichlet Kernels

# %% [markdown]
# ### Good kernels

# %% [markdown]
# ### Poisson kernels

# %% [markdown]
# # Ch 3

# %% [markdown]
# ## Convergence and Uniqeness of Fourier Series

# %% [markdown]
# #### Holder condition

# %% [markdown]
# #### Riemannn lebesgue lemma

# %% [markdown]
# #### Parseval's identity

# %% [markdown]
# #### Bessels inequality
