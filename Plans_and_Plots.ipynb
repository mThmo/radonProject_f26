# %% [markdown]
# 6/17/2026
# ### This summer,
# need to basically complete an acceptable project on Radon transform and FBP. With a python implementation that works on Shepp phantoms.
# - Reading list for this summer
#   - Stein shakarchi "vol 1. Fourier Analysis".
#     - skim/reread ch 2,3,5.
#     - heavy focus on chapter 6.
#     - Do applicable exercises and problems.
#   - Nievergelt "Computed tomography" UMAP module.
#     - read all
#     - do all exercises
#   - Olaffson and Quinto "Inverse problems".
#     - selected lectures
# - Deliverables:
#   - review paper
#     - Radon transform,
#     - fourier slice theorem proof,
#     - convolution theorem proof,
#     - fourier techniques for x ray analysis,
#     - Filtered Back Projection.
#     - Plancherel's theorem proof
#   - Python implementation of FBP on Shepp phantoms
#
#
# 6/24/2026
# ### During the fall,
# want to go a little more in depth on the theorems and analysis for FBP. And then do a more advanced application, such as Sliced wasserstein distance or something to do with ML.
# - Further Topics:
#   - spherical harmonics connections to radon transform
#   - Sliced Wasserstein distance
#   - Applications of SWD, such as in ML
#   - implementation of diffusion network with SWD as loss function
#   - Generalized Radon transform
#   - Generalized SWD
