# %% [markdown]
# 6/17/2026
# - This summer, need to basically complete an acceptable project on Radon transform and FBP. With a python implementation that works on Shepp phantoms.
# - Reading list for this summer
#   - Stein shakarchi "vol 1. Fourier Analysis", skim/reread intro chapters, focus on chapter 6
#   - Nievergelt "Computed tomography" UMAP module
#   - Olaffson and Quinto "Inverse problems"
# -
